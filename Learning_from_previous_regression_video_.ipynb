# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahiman001/Data-Science-learning-practice/blob/main/Learning_from_previous_regression_video_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ========================================================
# LINEAR REGRESSION — REFERENCE vs OUR PROJECT
# SHORT NOTES
# ========================================================

# REFERENCE PROJECT
# -----------------

# Dataset:
#     Boston Housing

# Model:
#     Multiple Linear Regression
#     → uses all 13 features

# Workflow:
#     Load data
#     ↓
#     DataFrame creation
#     ↓
#     Train/Test Split (70/30)
#     ↓
#     Standardization
#     ↓
#     LinearRegression()
#     ↓
#     Fit
#     ↓
#     10-Fold Cross-Validation
#     ↓
#     Predictions
#     ↓
#     Residual analysis
#     ↓
#     R²


# OUR PROJECT
# -----------

# Dataset:
#     California Housing

# Model:
#     Simple Linear Regression
#     → currently uses only MedInc

# Workflow:
#     Load data
#     ↓
#     Explore data
#     ↓
#     Check missing values/statistics
#     ↓
#     Correlation analysis
#     ↓
#     Select MedInc
#     ↓
#     Train/Test Split (80/20)
#     ↓
#     LinearRegression()
#     ↓
#     Fit
#     ↓
#     θ₀ and θ₁
#     ↓
#     Predictions
#     ↓
#     Actual vs Predicted
#     ↓
#     MSE
#     ↓
#     RMSE
#     ↓
#     R²
#     ↓
#     Regression plot


# ========================================================
# WHAT WE HAVE NOT DONE YET
# ========================================================

#     ☐ StandardScaler
#     ☐ Learn fit_transform vs transform
#     ☐ Data leakage from incorrect scaling
#     ☐ Cross-Validation
#     ☐ 10-Fold CV
#     ☐ neg_mean_squared_error
#     ☐ Residual calculation
#     ☐ Residual distribution / KDE
#     ☐ Multiple Linear Regression
#     ☐ Compare Simple vs Multiple Regression


# ========================================================
# LEARNINGS TO TAKE FROM HIS PROJECT
# ========================================================

# 1. STANDARDIZATION
#    ----------------
#    Learn:
#        StandardScaler
#        fit_transform(X_train)
#        transform(X_test)

#    Rule:
#        Fit preprocessing ONLY on training data.


# 2. CROSS-VALIDATION
#    -----------------
#    Learn:
#        cross_val_score()
#        cv=10
#        scoring="neg_mean_squared_error"

#    Purpose:
#        More reliable evaluation using multiple
#        train/validation splits.


# 3. RESIDUAL ANALYSIS
#    ------------------
#    Learn:
#        residual = y - ŷ
#        residual distribution
#        KDE plot

#    Purpose:
#        Understand how and where the model makes errors.


# 4. MULTIPLE LINEAR REGRESSION
#    ---------------------------
#    Learn:

#        ŷ = θ₀ + θ₁x₁ + θ₂x₂ + ... + θₙxₙ

#    Use multiple features instead of only MedInc.


# 5. MODEL EVALUATION
#    -----------------
#    We already learned:
#        MSE
#        RMSE
#        R²

#    Add:
#        Cross-validated MSE


# 6. DATA LEAKAGE
#    --------------
#    Learn why:

#        scaler.fit_transform(X_train)
#        scaler.transform(X_test)

#    is correct.


# ========================================================
# OUR LEARNING PATH FROM HERE
# ========================================================

# CURRENT:
#     Simple Linear Regression
#           ↓
#     Residual Analysis
#           ↓
#     Standardization
#           ↓
#     Cross-Validation
#           ↓
#     Multiple Linear Regression
#           ↓
#     Compare models
#           ↓
#     Final model evaluation


# KEY POINT:
#     We are NOT missing anything fundamental by not using
#     StandardScaler yet.

#     We deliberately started simpler so we understand
#     Linear Regression before adding the full ML workflow.
# ========================================================
