# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahiman001/Data-Science-learning-practice/blob/main/SQL_ALONG_WITH_PYTHON1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect(":memory:")

# %%
df = pd.read_csv("messy_customer_sales_data.csv")
df.head()
# Out:
#   Customer_ID               Name  Gender         Age         City Signup_Date  \
# 0    CUST4371        Paul Wilson      m         52.0     KOLKATA   2025-06-26
# 1    CUST5957       Jason Thomas       M  51.0 years          NaN  2021-02-17
# 2    CUST3754  Brittney Martinez       F        62.0   hyderabad   2023-11-05
# 3    CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad   2022-03-13
# 4    CUST5683    Matthew Carroll      f         41.0     CHENNAI   2024-04-05
#
#   Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 0         2025-05-17          26944.0             1.0
# 1         2025-07-22          44152.0             2.0
# 2         2024-12-08          31745.0             2.0
# 3         2025-10-02          39674.0             1.0
# 4         2024-12-15              NaN             8.0
#
#                       Email  Phone_Number Country
# 0  peckvictoria@example.com    2131107701   India
# 1  owensanthony@example.com    1080761560   india
# ...

# %%
df.to_sql( "customer_sales",conn,if_exists= "replace",index =False)
# Out:
# 10200

# %%
query = """
SELECT * FROM customer_sales
LIMIT 300
"""
pd.read_sql(query,conn)
# Out:
#     Customer_ID               Name  Gender         Age         City  \
# 0      CUST4371        Paul Wilson      m         52.0     KOLKATA
# 1      CUST5957       Jason Thomas       M  51.0 years         None
# 2      CUST3754  Brittney Martinez       F        62.0   hyderabad
# 3      CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad
# 4      CUST5683    Matthew Carroll      f         41.0     CHENNAI
# ..          ...                ...     ...         ...          ...
# 295    CUST2277       Jose Griffin       F        59.0       Delhi
# 296    CUST7503      Pamela Arnold      f         41.0   bangalore
# 297    CUST5403       Nicole Moore    MALE        25.0   Hyderabad
# 298        None       Jeffery Long    MALE        54.0     chennai
# 299    CUST8461         David Mora       F        51.0     kolkata
#
#     Signup_Date Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 0    2025-06-26         2025-05-17          26944.0             1.0
# ...

# %%
query = """
SELECT * FROM customer_sales
WHERE Age > 48
LIMIT 10
"""
pd.read_sql(query,conn)
# Out:
#   Customer_ID               Name  Gender         Age         City Signup_Date  \
# 0    CUST4371        Paul Wilson      m         52.0     KOLKATA   2025-06-26
# 1    CUST5957       Jason Thomas       M  51.0 years         None  2021-02-17
# 2    CUST3754  Brittney Martinez       F        62.0   hyderabad   2023-11-05
# 3    CUST1303        Sara Fuller  FEMALE        52.0   HYDERABAD   2025-04-11
# 4    CUST8398         James Ruiz    male        59.0     chennai   2024-08-07
# 5    CUST4080    Jacqueline Chen    MALE        65.0   hyderabad   2023-09-21
# 6    CUST9469    Randall Johnson       F        61.0       Delhi   2024-05-25
# 7    CUST3268         Adam Drake    MALE  54.0 years   bangalore   2024-07-21
# 8    CUST7752       Joshua Hayes       F        55.0   Bangalore   2022-07-07
# 9    CUST2922     Brittany Young    male        69.0   Hyderabad   2022-01-23
#
#   Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 0         2025-05-17          26944.0             1.0
# ...

# %%
query = """
SELECT * FROM customer_sales
WHERE Age !=48
LIMIT 10
"""
pd.read_sql(query,conn)
# Out:
#   Customer_ID               Name  Gender         Age         City Signup_Date  \
# 0    CUST4371        Paul Wilson      m         52.0     KOLKATA   2025-06-26
# 1    CUST5957       Jason Thomas       M  51.0 years         None  2021-02-17
# 2    CUST3754  Brittney Martinez       F        62.0   hyderabad   2023-11-05
# 3    CUST2934      Brenda Pierce  FEMALE        40.0   hyderabad   2022-03-13
# 4    CUST5683    Matthew Carroll      f         41.0     CHENNAI   2024-04-05
# 5    CUST3651      Laura Vincent    male        18.0   BANGALORE   2024-06-16
# 6   CUST10438     Timothy Dunlap       F  43.0 years   Hyderabad   2025-03-16
# 7    CUST5189     Sabrina Miller       F  40.0 years     CHENNAI   2025-07-07
# 8    CUST8237  Mr. Thomas Garcia       F        26.0         None  2025-05-24
# 9    CUST3260         Jason Mack    MALE        32.0   HYDERABAD   2024-08-14
#
#   Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 0         2025-05-17          26944.0             1.0
# ...

# %%
query = """
select * from customer_sales
WHERE  City LIKE  '%KOLKATA%'
LIMIT 10
"""
# HERE MY = THING DID NOT WORK AS THERE WERE  SPACES  IN THE COLUMN NAME AND MANY OTHER VARIABLES AND
# I COULDNT SEE IT SO I USED LIKE FUNCTION TO GET THE NAMES
pd.read_sql(query,conn)
# Out:
#   Customer_ID                Name  Gender         Age       City Signup_Date  \
# 0    CUST4371         Paul Wilson      m         52.0   KOLKATA   2025-06-26
# 1    CUST1516         William Day       F        None   kolkata   2021-05-02
# 2    CUST5950            Brad Lee  FEMALE  61.0 years   Kolkata   2024-12-01
# 3    CUST2485       Timothy Clark      f         56.0   Kolkata   2022-01-13
# 4    CUST4289       Anthony Ayala    MALE        68.0   Kolkata   2021-02-17
# 5    CUST1773         Samuel Wong      m         43.0   KOLKATA   2023-07-04
# 6    CUST3144         Nancy Scott    None        27.0   Kolkata   2021-06-23
# 7    CUST4352      Cynthia Nguyen      m         32.0   Kolkata   2023-02-10
# 8    CUST2280      Daniel Freeman    male        48.0   kolkata   2025-02-26
# 9    CUST2968  Christopher Nelson    male        37.0   kolkata   2025-06-12
#
#   Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 0         2025-05-17          26944.0             1.0
# ...

# %%
query = """ select count(*) from  customer_sales
"""
pd.read_sql(query,conn)
# Out:
#    count(*)
# 0     10200

# %%
query = """ select count(Age)from customer_sales
"""
pd.read_sql(query,conn)
# Out:
#    count(Age)
# 0        9249

# %%
query =""" select AVG(Age) from customer_sales
"""
pd.read_sql(query,conn)
# Out:
#     AVG(Age)
# 0  43.393772

# %%
query =""" select Min(Age) from customer_sales
"""
pd.read_sql(query,conn)
# Out:
#   Min(Age)
# 0      -10

# %%
query =""" select Max(Age) from customer_sales
"""
pd.read_sql(query,conn)
# Out:
#     Max(Age)
# 0  nan years

# %%
query = """ select City,avg(Purchase_Amount) as avg_purchase_amount from customer_sales
where Age > 45
and Feedback_Score > 5.0
group by city
order by avg_purchase_amount
"""
pd.read_sql(query,conn)
# Out:
#            City  avg_purchase_amount
# 0      CHENNAI          20583.327869
# 1      KOLKATA          21218.015873
# 2    hyderabad          22520.037975
# 3       mumbai          23323.534483
# 4      Kolkata          23506.695364
# 5      kolkata          23903.456522
# 6    HYDERABAD          24160.689189
# 7       Mumbai          24166.493333
# 8    Hyderabad          24298.519084
# 9        Delhi          24322.944056
# 10         None         24609.670103
# 11     Chennai          24809.781022
# 12   BANGALORE          25065.814286
# 13   Bangalore          25168.938776
# 14     chennai          25788.754098
# 15       delhi          26348.102041
# 16       DELHI          27213.452830
# 17      MUMBAI          28758.945205
# 18   bangalore         171173.900000

# %%
query =""" select trim(upper(City)),avg(Purchase_Amount) as avg_purchase_amount,
case when Feedback_Score >5.0  then 'Positive'
     when Feedback_Score = 5.0 then 'Mixed'
ELSE 'Negative'
end as Feedback_Type,
count(*)as total_customers
from customer_sales
where City is not null
group by trim(upper(City)),Feedback_Type
order by avg_purchase_amount
"""
pd.read_sql(query,conn)
# Out:
#    trim(upper(City))  avg_purchase_amount Feedback_Type  total_customers
# 0            CHENNAI         23453.820122      Negative              725
# 1          BANGALORE         23815.945736         Mixed              140
# 2            KOLKATA         23980.026891      Positive              662
# 3          HYDERABAD         24071.494845         Mixed              105
# 4            CHENNAI         24155.962901      Positive              677
# 5            KOLKATA         24604.916667      Negative              736
# 6             MUMBAI         24615.383459         Mixed              140
# 7             MUMBAI         24713.741732      Positive              697
# 8              DELHI         24840.837971      Positive              683
# 9          HYDERABAD         24939.417840      Positive              704
# 10             DELHI         25273.904321      Negative              705
# 11         BANGALORE         25403.520593      Negative              683
# ...
